# %% [markdown]
# <a href="https://colab.research.google.com/github/odielo/odielo/blob/main/SIR_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from scipy.optimize import minimize

# Load and preprocess the COVID-19 dataset
# Be sure to replace 'path_to_file' with the actual file path
# covid_data = pd.read_csv('path_to_file')
# Preprocess data to get daily cases, recoveries, and currently infected individuals

# Define the SIR model differential equations.
def sir_model(y, t, Beta, Gamma):
    S, I, R = y
    dSdt = -Beta * S * I
    dIdt = Beta * S * I - Gamma * I
    dRdt = Gamma * I
    return dSdt, dIdt, dRdt

# Total population, N.
N = # Total population
# Initial number of infected and recovered individuals, I0 and R0.
I0, R0 = # Initial conditions from dataset
# Everyone else, S0, is susceptible to infection initially.
S0 = N - I0 - R0
# Initial conditions vector
y0 = S0, I0, R0

# Define time points (days)
t = np.linspace(0, # days, # data points)

# Integrate the SIR equations over the time grid, t.
ret = odeint(sir_model, y0, t, args=(Beta, Gamma))
S, I, R = ret.T

# Plot the data on three separate curves for S(t), I(t), and R(t)
plt.figure(figsize=(12, 8))
plt.plot(t, S, 'b', label='Susceptible')
plt.plot(t, I, 'r', label='Infected')
plt.plot(t, R, 'g', label='Recovered')
plt.title('SIR model')
plt.xlabel('Days')
plt.ylabel('Number of people')
plt.legend(loc='best')
plt.show()

# Define objective function for optimisation (comparing to actual data)
def objective_function(params):
    # Define model with the current parameter guess
    # Compare model output with actual data
    # Calculate a measure of fit (e.g., sum of squares)
    # return the measure of fit

# Model fitting to find Beta and Gamma (requires actual data)
# initial_guess = [Beta_guess, Gamma_guess]
# result = minimize(objective_function, initial_guess, method='L-BFGS-B')
# Beta_est, Gamma_est = result.x
# Out:
#   File "<ipython-input-1-13f5eae7db3d>", line 20
#     N = # Total population
#         ^
# SyntaxError: invalid syntax

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# A hypothetical dataset
# Assume a small population size (in this case, 10000 people)
N = 10000
# Initial conditions: one infected, no recovered individuals, and the rest susceptible
I0 = 1
R0 = 0
S0 = N - I0 - R0

# Contact rate, beta, and mean recovery rate, gamma, (in 1/days)
beta = 0.3
gamma = 0.1

# A grid of time points (in days)
t = np.linspace(0, 160, 160)

# The SIR model differential equations
def deriv(y, t, N, beta, gamma):
    S, I, R = y
    dSdt = -beta * S * I / N
    dIdt = beta * S * I / N - gamma * I
    dRdt = gamma * I
    return dSdt, dIdt, dRdt

# Initial conditions vector
y0 = S0, I0, R0

# Integrate the SIR equations over t
ret = odeint(deriv, y0, t, args=(N, beta, gamma))
S, I, R = ret.T

# Plotting the results
plt.figure(figsize=(12, 6))
plt.plot(t, S, 'b', label='Susceptible')
plt.plot(t, I, 'r', label='Infected')
plt.plot(t, R, 'g', label='Recovered')
plt.title("SIR Model (Hypothetical COVID-19 Data)")
plt.xlabel('Days')
plt.ylabel('Number of People')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# A hypothetical dataset
# Assume a small population size (in this case, 10000 people)
N = 10000
# Initial conditions: one infected, no recovered individuals, and the rest susceptible
I0 = 1
R0 = 0
S0 = N - I0 - R0

# Contact rate, beta, and mean recovery rate, gamma, (in 1/days)
beta = 0.3
gamma = 0.1

# A grid of time points (in days)
t = np.linspace(0, 160, 160)

# The SIR model differential equations
def deriv(y, t, N, beta, gamma):
    S, I, R = y
    dSdt = -beta * S * I / N
    dIdt = beta * S * I / N - gamma * I
    dRdt = gamma * I
    return dSdt, dIdt, dRdt

# Initial conditions vector
y0 = S0, I0, R0

# Integrate the SIR equations over t
ret = odeint(deriv, y0, t, args=(N, beta, gamma))
S, I, R = ret.T

# Plotting the results
plt.figure(figsize=(12, 6))
plt.plot(t, S, 'b', label='Susceptible')
plt.plot(t, I, 'r', label='Infected')
plt.plot(t, R, 'g', label='Recovered')
plt.title("SIR Model (Hypothetical COVID-19 Data)")
plt.xlabel('Days')
plt.ylabel('Number of People')
plt.legend(loc='best')
plt.grid(True)
plt.show()
